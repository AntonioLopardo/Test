# %%
import os
os.chdir('/home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/SenatoPlur')

# %%
os.chdir('/home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/SenatoPlur/Destra')
for Reg in os.listdir():
    pre_reg = os.getcwd()
    dir_string_reg = os.path.join(pre_reg, Reg)
    os.chdir(dir_string_reg)
    print(os.getcwd())
    for search_term in os.listdir():
        pre_term = os.getcwd()
        dir_string_term = os.path.join(dir_string_reg, search_term)
        os.chdir(dir_string_term)
        print(pre_term)
        for file in os.listdir():
            os.remove(file)
            print('removing:' + file)
        
        os.chdir(pre_term)
        print('fine' + os.getcwd())
    os.chdir(pre_reg)
# Out:
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/SenatoPlur/Destra/Toscana02-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/SenatoPlur/Destra/Toscana02-b
# removing:Lega_2018-02-24_to_2018-03-02.json
# fine/home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/SenatoPlur/Destra/Toscana02-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/SenatoPlur/Destra/Toscana02-b
# fine/home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/SenatoPlur/Destra/Toscana02-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/SenatoPlur/Destra/Toscana02-b
# fine/home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/SenatoPlur/Destra/Toscana02-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/SenatoPlur/Destra/Toscana02-b
# fine/home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/SenatoPlur/Destra/Toscana02-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/SenatoPlur/Destra/Toscana02-b
# fine/home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/SenatoPlur/Destra/Toscana02-b
# ...

# %%
os.chdir('/home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S')
for Reg in os.listdir():
    pre_reg = os.getcwd()
    dir_string_reg = os.path.join(pre_reg, Reg)
    os.chdir(dir_string_reg)
    print(os.getcwd())
    for file in os.listdir():
        os.rmdir(file)
        print('removing:' + file)

    os.chdir(pre_reg)
os.chdir(pre_reg)
# Out:
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Piemonte
# removing:DiBattista
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-931fa6790cae> in <module>()
#       6     print(os.getcwd())
#       7     for file in os.listdir():
# ----> 8         os.rmdir(file)
#       9         print('removing:' + file)
#      10
#
# OSError: [Errno 39] Directory not empty: 'Grillo'

# %%
os.chdir('/home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/TestDist/Destra')
for Reg in os.listdir():
    os.rmdir(Reg)
    print('removing:' + Reg)
# Out:
# removing:Sicilia
# removing:.ipynb_checkpoints
# removing:Veneto
# removing:Toscana

# %%
Regioni_list = ['Toscana',
              'Veneto',
                 'Piemonte',
                 'Lazio',
                 'Sicilia',
                'Abruzzo',
                 'Molise',
               'Basilicata',
                 'Calabria',
                'Puglia',
                 'Liguria',
                'Sardegna',
                'ValledAosta',
               'Friuli',
                'Trentino',
                'Campania',
                'Umbria',
                 'Lombardia',
                 'Marche']

# %%
os.chdir('/home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/TestDist/Sinistra')
dir_name_del = os.getcwd()

for Reg in Regioni_list:
    os.mkdir(os.path.join(dir_name_del, Reg))
    print('Creating:'+ Reg)
# Out:
# Creating:Toscana
# Creating:Veneto
# Creating:Piemonte
# Creating:Lazio
# Creating:Sicilia
# Creating:Abruzzo
# Creating:Molise
# Creating:Basilicata
# Creating:Calabria
# Creating:Puglia
# Creating:Liguria
# Creating:Sardegna
# Creating:ValledAosta
# Creating:Friuli
# Creating:Trentino
# Creating:Campania
# Creating:Umbria
# Creating:Lombardia
# Creating:Marche
