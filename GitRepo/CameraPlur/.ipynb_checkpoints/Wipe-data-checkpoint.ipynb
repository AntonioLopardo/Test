# %%
import os
os.chdir('/home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur')

# %%
os.chdir('/home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S')
for Reg in os.listdir():
    pre_reg = os.getcwd()
    dir_string_reg = os.path.join(pre_reg, Reg)
    os.chdir(dir_string_reg)
    print(os.getcwd())
    for search_term in os.listdir():
        pre_term = os.getcwd()
        dir_string_term = os.path.join(dir_string_reg, search_term)
        os.chdir(dir_string_term)
        print(pre_term)
        for file in os.listdir():
            os.remove(file)
            print('removing:' + file)
        
        os.chdir(pre_term)
        print('fine' + os.getcwd())
    os.chdir(pre_reg)
# Out:
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Piemonte2-01-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Veneto2-03-d
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Emilia-Romagna-04-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Toscana-04-d
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Campania1-03-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia3-01-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Piemonte1-02-d
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia1-04-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lazio1-03-e
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Emilia-Romagna-04-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lazio2-01-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia1-04-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia4-02-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia2-02-f
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lazio1-03-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Calabria-01-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Emilia-Romagna-02-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lazio2-01-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lazio1-03-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Liguria-01-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Abruzzo-02-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Liguria-02-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Piemonte1-02-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Emilia-Romagna-04-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Toscana-04-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia1-02-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Campania2-03-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Sicilia1-02-e
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia1-04-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Veneto1-02-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia3-01-g
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Sardegna-02-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Piemonte1-02-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Campania1-02-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Sicilia2-03-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Puglia-03-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia3-01-h
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Marche-02-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Emilia-Romagna-03-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Sicilia2-02-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lazio1-01-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Toscana-02-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Emilia-Romagna-02-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Piemonte2-01-d
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Campania1-01-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Campania1-01-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Sicilia1-03-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia1-02-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia2-02-e
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Sicilia1-02-g
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia4-02-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia2-02-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Toscana-02-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Veneto2-01-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Toscana-01-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Piemonte2-01-f
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Piemonte2-01-e
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Campania2-01-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Toscana-01-d
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Sicilia2-01-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lazio1-01-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Piemonte2-01-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lazio1-03-d
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Sicilia1-02-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia3-01-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Umbria-01-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Veneto2-03-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Toscana-04-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia4-01-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Calabria-02-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Friuli-01-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lazio1-02-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Marche-01-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Marche-02-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Sicilia2-01-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia3-01-d
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia2-02-d
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Veneto2-03-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Marche-02-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Puglia-01-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Campania2-01-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Toscana-03-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Abruzzo-02-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Veneto2-02-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Sardegna-01-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Toscana-03-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Puglia-03-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Veneto2-03-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Sicilia1-02-f
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Emilia-Romagna-01-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Sicilia1-02-d
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Campania1-03-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia2-02-g
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia2-01-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia4-01-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Puglia-02-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Veneto1-01-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Toscana-01-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lazio2-02-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Sicilia2-03-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lazio1-01-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Campania2-03-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lazio1-02-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Trentino-01-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia4-01-d
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia4-02-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Molise-01-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia3-01-e
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia2-01-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Sicilia1-02-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Puglia-03-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Emilia-Romagna-02-e
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Campania1-01-e
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Campania1-01-d
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Puglia-04-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Toscana-04-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lazio1-02-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Basilicata-01-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Liguria-02-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia4-01-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lazio2-02-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Campania1-01-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Sicilia1-01-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia2-01-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia1-03-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Calabria-02-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Piemonte2-01-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Piemonte1-01-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Piemonte2-02-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Emilia-Romagna-01-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia2-02-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia3-01-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lazio2-01-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Abruzzo-02-d
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lazio1-03-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Toscana-01-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Puglia-03-d
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Toscana-03-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Sicilia2-02-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Abruzzo-02-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Sicilia2-02-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Calabria-01-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Sicilia2-01-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia3-01-f
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Sicilia1-02-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Campania2-03-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Campania2-02-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Calabria-02-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Calabria-01-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Lombardia2-02-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Piemonte2-02-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Abruzzo-01-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Emilia-Romagna-02-d
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Sicilia1-03-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Emilia-Romagna-02-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Campania1-03-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Veneto1-01-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Puglia-02-b
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Piemonte1-02-c
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Liguria-01-a
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Piemonte2-02-b

# %%
os.chdir('/home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S')
for Reg in os.listdir():
    pre_reg = os.getcwd()
    dir_string_reg = os.path.join(pre_reg, Reg)
    os.chdir(dir_string_reg)
    print(os.getcwd())
    for file in os.listdir():
        os.rmdir(file)
        print('removing:' + file)

    os.chdir(pre_reg)
os.chdir(pre_reg)
# Out:
# /home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/CameraPlur/M5S/Piemonte
# removing:DiBattista
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-931fa6790cae> in <module>()
#       6     print(os.getcwd())
#       7     for file in os.listdir():
# ----> 8         os.rmdir(file)
#       9         print('removing:' + file)
#      10
#
# OSError: [Errno 39] Directory not empty: 'Grillo'

# %%
os.chdir('/home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/TestDist/Destra')
for Reg in os.listdir():
    os.rmdir(Reg)
    print('removing:' + Reg)
# Out:
# removing:Sicilia
# removing:.ipynb_checkpoints
# removing:Veneto
# removing:Toscana

# %%
Regioni_list = ['Toscana',
              'Veneto',
                 'Piemonte',
                 'Lazio',
                 'Sicilia',
                'Abruzzo',
                 'Molise',
               'Basilicata',
                 'Calabria',
                'Puglia',
                 'Liguria',
                'Sardegna',
                'ValledAosta',
               'Friuli',
                'Trentino',
                'Campania',
                'Umbria',
                 'Lombardia',
                 'Marche']

# %%
os.chdir('/home/antoniolopardo/Desktop/myRNN/mySentRNN_v0.02/TestDist/Sinistra')
dir_name_del = os.getcwd()

for Reg in Regioni_list:
    os.mkdir(os.path.join(dir_name_del, Reg))
    print('Creating:'+ Reg)
# Out:
# Creating:Toscana
# Creating:Veneto
# Creating:Piemonte
# Creating:Lazio
# Creating:Sicilia
# Creating:Abruzzo
# Creating:Molise
# Creating:Basilicata
# Creating:Calabria
# Creating:Puglia
# Creating:Liguria
# Creating:Sardegna
# Creating:ValledAosta
# Creating:Friuli
# Creating:Trentino
# Creating:Campania
# Creating:Umbria
# Creating:Lombardia
# Creating:Marche
