# %%
import os
os.getcwd()
import warnings 
warnings.simplefilter('ignore')

# %%
os.chdir('/home/antoniolopardo/Desktop/Test')
if os.path.isdir('Demo') == True:
    for root, dirs, filez in os.walk('Demo', topdown=False):
        for name in filez:
            os.remove(os.path.join(root, name))
        for name in dirs:
            os.rmdir(os.path.join(root, name))

    os.rmdir('Demo')

os.chdir('/home/antoniolopardo/Desktop/Test')
data_dir_name = 'Demo'
os.mkdir(data_dir_name)

# %%
''' !!! WATCH OUT !!! 

Creating and displaying map, here using the geojson polygons 
the user should try to approximate with multiple circles his target search zones, 
after every search zone, not every circle, the user should export the circle thanks 
to the button in the upper right. The csv of the circles for the single search zone
should be saved with exactly the same name as the search zone, visible onClick 
thanks to a pop up, in a directory named draw_data. This directory should then be 
compress in a .zip (No .rar No .7zip )

# !!! WATCH OUT !!!'''

map_up_dir = 'COLL_LAZIO_CAMERA_PLUR_2018.geojson'

os.chdir('/home/antoniolopardo/Desktop/Test')
import folium
import Folium_map_mod as fm

os.chdir(data_dir_name)

m = fm.data_entry_map(map_dir = map_up_dir)

m
# Out:
# List of features from your map:
#
# ['CAM17P_COD', 'SEGGI_UNI', 'Shape_Leng', 'Shape_Area', 'SEGGI_PRO', 'OBJECTID', 'CAM17P_DEN', 'POP_2011', 'SEGGI_TOT']
#
#
# Name exactly the feature that containes the labels(e.g. NAME): CAM17P_DEN
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
os.chdir('/home/antoniolopardo/Desktop/Test/Demo')
# !unzip draw_data
# Out:
# Archive:  draw_data.zip
#    creating: draw_data/
#   inflating: draw_data/Lazio1-01.csv
#   inflating: draw_data/Lazio1-02.csv
#   inflating: draw_data/Lazio1-03.csv
#   inflating: draw_data/Lazio2-01.csv
#   inflating: draw_data/Lazio2-02.csv

# %%
os.chdir('/home/antoniolopardo/Desktop/Test')
# %run -i 'file_writer_mod.py' 'Demo'
# Out:
# Missing or multiple MAP geojson files
#
# ['new_COLL_LAZIO_CAMERA_PLUR_2018.geojson', 'COLL_LAZIO_CAMERA_PLUR_2018.geojson']
# Which is the right file?COLL_LAZIO_CAMERA_PLUR_2018.geojson
# List of features from your map:
#
# ['SEGGI_PRO', 'CAM17P_DEN', 'CAM17P_COD', 'OBJECTID', 'SEGGI_UNI', 'Shape_Area', 'SEGGI_TOT', 'POP_2011', 'Shape_Leng']
#
#
# Name exactly the feature that containes the labels(e.g. NAME): CAM17P_DEN

# %%
os.chdir('/home/antoniolopardo/Desktop/Test')
# %run -i 'SearchAlgo.py' 'Demo'
# Out:
#              SEARCH_TERMS
# SEARCH_GROUP
# Salato              Pizza
# Dolce               Torta
# Dolce
# ['Torta']
# Salato
# ['Pizza']
# ['Dolce', 'Salato']
#                                                FILE
# TYPE
# regions_list                         LIST_ZONES.csv
# coor_dict                            COOR_ZONES.csv
# map             COLL_LAZIO_CAMERA_PLUR_2018.geojson
# labels_feature                           CAM17P_DEN
#                                                        COOR
# ZONES
# Lazio2-01-a  42.342305278572816,12.815551757812502,32.882km
# Lazio2-01-b   42.353850367002394,11.90274238586426,48.304km
# Lazio1-01-a   42.00338672135351,12.413177490234377,12.269km
# Lazio1-01-b    41.9092717909289,12.617561817169191,11.136km
# Lazio2-02-a   41.577828526911446,13.52322578430176,40.178km
# Lazio2-02-b   41.41389556467733,12.886962890625002,24.610km
# Lazio1-02-a  41.781552998900345,12.271728515625002,23.632km
# ...

# %%
os.chdir('/home/antoniolopardo/Desktop/Test')
import warnings
warnings.simplefilter('ignore')
# %run -i 'pop_general.py' 'Demo' 'it'
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py:1188: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py:1290: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# ...
